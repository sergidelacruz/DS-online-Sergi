# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre conceptos básicos de Matplotlib, completa los siguientes ejercicios. Recuerda que necesitarás datos que están en el directorio data que acompaña al notebook (búscalo en el repositorio de ejercicios)
#
# La solución a los mismos las tienes ya, intenta no mirarlos de primeras pero no dejes de hacerlo cuando hayas terminado por si te pudieran aportar.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Ejercicio 1
#
# Construye la siguiente figura con dos subplots utilizando el estilo MATLAB (es decir plt.\<funcion\>, no usando objetos `Axes`)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.subplot(1,2,1)
plt.plot(x, np.sin(x))
plt.title("Seno")

plt.subplot(1,2,2)
plt.plot(x, np.cos(x))
plt.title("Coseno");

# %% [markdown]
# ### Ejercicio 2
#
# Reproduce la imagen de la figura usando tres subplots en una columna, utilizando objetos `Axes`. Las dos primeras son las funciones anteriores y la tercera es la tangente (np.tan)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0, 1, 0.2], xticklabels=[0,0,2,4,6,8,10,12])
ax2 = fig.add_axes([0.1, -0.3, 1, 0.2], xticklabels=[0,0,2,4,6,8,10,12])
ax3 = fig.add_axes([0.1, -0.6, 1, 0.2], xticklabels=[0,0,2,4,6,8,10,12], ylim=(-40, 20))

x = np.linspace(0, 10)
ax1.plot(np.sin(x), 'r')
ax2.plot(np.cos(x), 'g')
ax3.plot(np.tan(x));
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_19444\1593800223.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1 = fig.add_axes([0.1, 0, 1, 0.2], xticklabels=[0,0,2,4,6,8,10,12])
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_19444\1593800223.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2 = fig.add_axes([0.1, -0.3, 1, 0.2], xticklabels=[0,0,2,4,6,8,10,12])
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_19444\1593800223.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax3 = fig.add_axes([0.1, -0.6, 1, 0.2], xticklabels=[0,0,2,4,6,8,10,12], ylim=(-40, 20))

# %% [markdown]
# ### Ejercicio 3: Ajuste de Colores y Estilos de Línea
#
# Modifica la primera figura para que se muestre de la siguiente manera

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.subplot(1,2,1)
plt.plot(x, np.sin(x), '--m')
plt.title("Seno")

plt.subplot(1,2,2)
plt.plot(x, np.cos(x), '-.c')
plt.title("Coseno");

# %% [markdown]
# ### Ejercicio 4
#
# Reproduce la figura siguiente. Recuerda que las funciones seno hiperbólico y coseno hiperbólico se obtienen así:
# * np.sinh, seno hiperbólico;
# * np.cosh, coseno hiperbólico;

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.subplot(2,1,1)
plt.plot(x, np.sinh(x), "r")
plt.title("Seno Hiperbólico")
plt.ylabel("sinh(x)")
plt.xlabel("x")

fig = plt.subplot(2,1,2)
plt.plot(x, np.cosh(x))
plt.title("Coseno Hiperbólico")
plt.ylabel("cosh(x)")
plt.xlabel("x")

plt.subplots_adjust(hspace = 0.6, wspace = 1)

# %% [markdown]
# ### Ejercicio 5: Ajustando el Espaciado de Subplots
#
# Reproduce la siguiente figura con cuatro subplots, ajusta el espaciado entre los subplots para evitar la superosición (tal y como ves en la figura), emplea `subplots_adjust` y los parámetros hspace y wspace.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig,ax = plt.subplots(2,2)

ax[0,0].plot(x,np.sin(x))
ax[0,1].plot(x,np.cos(x))
ax[1,0].plot(x,np.tan(x))
ax[1,1].plot(x,np.log(x))

plt.subplots_adjust(hspace = 0.4, wspace = 0.4)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_19444\229621661.py:6: RuntimeWarning: divide by zero encountered in log
#   ax[1,1].plot(x,np.log(x))

# %% [markdown]
# ### Ejercicio 6:
#
# Reproduce la figura siguiente empleando sólo el estilo MATLAB (plt.\<funcion>\) y creando solo el contenido de los dos primeros gráficos (fila 1). Luego usa el estilo con métodos (objetos `axes`) para añadir el tercer gráfico.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig,ax = plt.subplots(2,1)

ax[0].plot(x,np.sin(x))
ax[0].plot(x,np.sqrt(x),"orange")
ax[0].set_title("Raíz Cuadrada y coseno")

ax[1].plot(x,np.cos(x))
plt.title("Seno")

plt.subplots_adjust(hspace = 0.4, wspace = 0.4)

# %% [markdown]
# ### Ejercicio 7
#
# Para terminar, reproduce la imagen de la figura

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
y  = np.linspace(0, 10, 150) 
plt.plot(y,np.sin(y), marker='o', color='yellow', markeredgewidth=2,markersize=8, markeredgecolor='blue', linestyle='None')
plt.title("Ejemplo de Marcadores");
