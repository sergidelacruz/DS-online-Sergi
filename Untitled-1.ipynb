# %%
import pandas as pd
import requests
pd.options.mode.copy_on_write = True

# %%
url = "https://iepnb.gob.es/api/especie/v_idnombre_comun_api"

# %%
respuesta_usa = requests.get(url)
print(respuesta_usa.status_code)
# Out:
# 404

# %%
datos_usa = respuesta_usa.json()
datos_usa
# Out:
# {'code': '42P01',
#  'details': None,
#  'hint': None,
#  'message': 'relation "api_especie.v_idnombre_comun_api" does not exist'}

# %%
datos_usa.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 datos_usa.info()
#
# AttributeError: 'dict' object has no attribute 'info'

# %%
animals = pd.read_csv("C:/Users/Usuario/Downloads/prova.csv")
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_16688\2020868769.py:1: DtypeWarning: Columns (3,4,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   animals = pd.read_csv("C:/Users/Usuario/Downloads/prova.csv")

# %%
animals.sample(5)
# Out:
#        idtaxon  idnombre                                     ScientificName  \
# 1371      2024      2024                            Allium schoenoprasum L.
# 47455    59597     59597                    Masistylum arcuatum (Mik, 1863)
# 24426    35979     35979  Protoperidinium curtipes (Jørgensen, 1912) Bal...
# 4093      5368      5368                          Impatiens noli-tangere L.
# 40996    52979     52979  Cyaniris semiargus tartessus Gil-T. y Huertas,...
#
#                                           taxonConceptID ScientificNameID  \
# 1371   urn:lsid:recibio.net:taxon:e11046bb-b6ce-4d44-...              NaN
# 47455                                                NaN              NaN
# 24426                                                NaN              NaN
# 4093   urn:lsid:recibio.net:taxon:c97ad4f1-3b2a-446f-...              NaN
# 40996                                                NaN              NaN
#
#                                          nameAccordingto  \
# ...

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68929 entries, 0 to 68928
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   idtaxon                   68929 non-null  int64
#  1   idnombre                  68929 non-null  int64
#  2   ScientificName            68929 non-null  object
#  3   taxonConceptID            7457 non-null   object
#  4   ScientificNameID          694 non-null    object
#  5   nameAccordingto           7610 non-null   object
#  6   namePublishedIn           9396 non-null   object
#  7   namePublishedInYear       7194 non-null   float64
#  8   kingdom                   68929 non-null  object
#  9   phylum                    68929 non-null  object
#  10  class                     68926 non-null  object
#  11  order                     68922 non-null  object
#  12  family                    68902 non-null  object
# ...

# %%
estado = pd.read_csv("C:/Users/Usuario/Downloads/prova2.csv")
estado
# Out:
#     idtaxon  idestadoconservacion  estadoconservacion  anio  idcategoria  \
# 0         1                   NaN                 NaN  2000           11
# 1         1                   NaN                 NaN  2004           11
# 2         1                   NaN                 NaN  2008           11
# 3         1                   NaN                 NaN  2010           11
# 4         1                   NaN                 NaN  2011           11
# 5         1                   NaN                 NaN  2012           39
# 6         1                   NaN                 NaN  2017           11
# 7         1                   NaN                 NaN  2018           39
# 8         2                   NaN                 NaN  2000           11
# 9         2                   NaN                 NaN  2004           11
# 10        2                   NaN                 NaN  2006           11
# 11        2                   NaN                 NaN  2008           11
# ...
